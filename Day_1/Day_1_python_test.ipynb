# %% [markdown]
# # DS 5030 — Day 1 Setup Test
#
# Run this notebook top to bottom, then commit and push it to **your own fork**. If the last cell prints
# `SETUP CODE: UU-92-5650`, your environment works.
#
# **Before you run anything, look at the top right of this window.** The kernel must say **`uu`**. If it says
# `base`, `Python 3`, or `Select Kernel`, click it and choose the `uu` environment. Running with the wrong
# kernel is the single most common problem in this class, and it wastes hours.

# %% [markdown]
# ## 0. Who is this?
#
# Fill in both, so the copy you push identifies you. Then run the cell.

# %%
NAME = "Hannah Sweazey"             # e.g. "Ada Lovelace"
GITHUB_USERNAME = "HSweazey"  # e.g. "alovelace"

if not NAME or not GITHUB_USERNAME:
    print("Fill in NAME and GITHUB_USERNAME above, then run this cell again.")
else:
    print(f"{NAME} ({GITHUB_USERNAME})")
# Out:
# Fill in NAME and GITHUB_USERNAME above, then run this cell again.

# %% [markdown]
# ## 1. Are the six packages installed?
#
# Every session this semester uses these. You should get a version number for each one; the numbers
# themselves do not need to match anybody else's.

# %%
import sys
import numpy, pandas, matplotlib, seaborn, scipy, statsmodels

for m in (numpy, pandas, matplotlib, seaborn, scipy, statsmodels):
    print(f"{m.__name__:12s} {m.__version__}")

print()
print("python     ", sys.version.split()[0])
print("interpreter", sys.executable)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 import sys
# ----> 2 import numpy, pandas, matplotlib, seaborn, scipy, statsmodels
#       3
#       4 for m in (numpy, pandas, matplotlib, seaborn, scipy, statsmodels):
#       5     print(f"{m.__name__:12s} {m.__version__}")
#
# File /opt/anaconda3/envs/uu/lib/python3.12/site-packages/seaborn/__init__.py:2
#       1 # Import seaborn objects
# ----> 2 from .rcmod import *  # noqa: F401,F403
#       3 from .utils import *  # noqa: F401,F403
#       4 from .palettes import *  # noqa: F401,F403
#
# File /opt/anaconda3/envs/uu/lib/python3.12/site-packages/seaborn/rcmod.py:5
#       3 import matplotlib as mpl
#       4 from cycler import cycler
# ----> 5 from . import palettes
#       8 __all__ = ["set_theme", "set", "reset_defaults", "reset_orig",
#       9            "axes_style", "set_style", "plotting_context", "set_context",
#      10            "set_palette"]
#      13 _style_keys = [
#      14
#      15     "axes.facecolor",
#    (...)     50
#      51 ]
#
# File /opt/anaconda3/envs/uu/lib/python3.12/site-packages/seaborn/palettes.py:9
#       5 import matplotlib as mpl
#       7 from .external import husl
# ----> 9 from .utils import desaturate, get_color_cycle
#      10 from .colors import xkcd_rgb, crayons
#      11 from ._compat import get_colormap
#
# File /opt/anaconda3/envs/uu/lib/python3.12/site-packages/seaborn/utils.py:14
#      12 import matplotlib as mpl
#      13 from matplotlib.colors import to_rgb
# ---> 14 import matplotlib.pyplot as plt
#      15 from matplotlib.cbook import normalize_kwargs
#      17 from seaborn._core.typing import deprecated
#
# File /opt/anaconda3/envs/uu/lib/python3.12/site-packages/matplotlib/pyplot.py:61
#      59 from cycler import cycler  # noqa: F401
#      60 import matplotlib
# ---> 61 import matplotlib.image
#      62 from matplotlib import _api
#      63 # Re-exported (import x as x) for typing.
#
# File /opt/anaconda3/envs/uu/lib/python3.12/site-packages/matplotlib/image.py:24
#      22 import matplotlib.artist as martist
#      23 import matplotlib.colorizer as mcolorizer
# ---> 24 from matplotlib.backend_bases import FigureCanvasBase
#      25 import matplotlib.colors as mcolors
#      26 from matplotlib.transforms import (
#      27     Affine2D, BboxBase, Bbox, BboxTransform, BboxTransformTo,
#      28     IdentityTransform, TransformedBbox)
#
# File /opt/anaconda3/envs/uu/lib/python3.12/site-packages/matplotlib/backend_bases.py:49
#      46 import numpy as np
#      48 import matplotlib as mpl
# ---> 49 from matplotlib import (
#      50     _api, backend_tools as tools, cbook, colors, _docstring, text,
#      51     _tight_bbox, transforms, widgets, is_interactive, rcParams)
#      52 from matplotlib._pylab_helpers import Gcf
#      53 from matplotlib.backend_managers import ToolManager
#
# File /opt/anaconda3/envs/uu/lib/python3.12/site-packages/matplotlib/text.py:18
#      16 from . import _api, artist, cbook, _docstring, colors as mcolors
#      17 from .artist import Artist
# ---> 18 from .font_manager import FontProperties, fontManager, get_font
#      19 from .patches import FancyArrowPatch, FancyBboxPatch, Rectangle
#      20 from .textpath import TextPath, TextToPath  # noqa # Logically located here
#
# File /opt/anaconda3/envs/uu/lib/python3.12/site-packages/matplotlib/font_manager.py:1851
#    1847     _log.info("generated new fontManager")
#    1848     return fm
# -> 1851 fontManager = _load_fontmanager()
#    1852 findfont = fontManager.findfont
#    1853 get_font_names = fontManager.get_font_names
#
# File /opt/anaconda3/envs/uu/lib/python3.12/site-packages/matplotlib/font_manager.py:1845, in _load_fontmanager(try_read_cache)
#    1843             _log.debug("Using fontManager instance from %s", fm_path)
#    1844             return fm
# -> 1845 fm = FontManager()
#    1846 json_dump(fm, fm_path)
#    1847 _log.info("generated new fontManager")
#
# File /opt/anaconda3/envs/uu/lib/python3.12/site-packages/matplotlib/font_manager.py:1257, in FontManager.__init__(self, size, weight)
#    1254 try:
#    1255     for fontext in ["afm", "ttf"]:
#    1256         for path in [*findSystemFonts(paths, fontext=fontext),
# -> 1257                      *findSystemFonts(fontext=fontext)]:
#    1258             try:
#    1259                 self.addfont(path)
#
# File /opt/anaconda3/envs/uu/lib/python3.12/site-packages/matplotlib/font_manager.py:313, in findSystemFonts(fontpaths, fontext)
#     311 installed_fonts = _get_fontconfig_fonts()
#     312 if sys.platform == 'darwin':
# --> 313     installed_fonts += _get_macos_fonts()
#     314     fontpaths = [*X11FontDirectories, *OSXFontDirectories]
#     315 else:
#
# File /opt/anaconda3/envs/uu/lib/python3.12/site-packages/matplotlib/font_manager.py:272, in _get_macos_fonts()
#     269 """Cache and list the font paths known to ``system_profiler SPFontsDataType``."""
#     270 try:
#     271     d, = plistlib.loads(
# --> 272         subprocess.check_output(["system_profiler", "-xml", "SPFontsDataType"]))
#     273 except (OSError, subprocess.CalledProcessError, plistlib.InvalidFileException):
#     274     return []
#
# File /opt/anaconda3/envs/uu/lib/python3.12/subprocess.py:466, in check_output(timeout, *popenargs, **kwargs)
#     463         empty = b''
#     464     kwargs['input'] = empty
# --> 466 return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
#     467            **kwargs).stdout
#
# File /opt/anaconda3/envs/uu/lib/python3.12/subprocess.py:550, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     548 with Popen(*popenargs, **kwargs) as process:
#     549     try:
# --> 550         stdout, stderr = process.communicate(input, timeout=timeout)
#     551     except TimeoutExpired as exc:
#     552         process.kill()
#
# File /opt/anaconda3/envs/uu/lib/python3.12/subprocess.py:1196, in Popen.communicate(self, input, timeout)
#    1194     self._stdin_write(input)
#    1195 elif self.stdout:
# -> 1196     stdout = self.stdout.read()
#    1197     self.stdout.close()
#    1198 elif self.stderr:
#
# KeyboardInterrupt:

# %% [markdown]
# **Check the `interpreter` line.** It has to contain `/uu/` (or `\uu\` on Windows). If it does not, this
# notebook is running a different Python than the one your packages went into, and you may run into issues below or later in the semester. Fix the kernel before continuing.

# %% [markdown]
# ## 2. Can you read a data file and draw a picture?
#
# `cville_cars.csv` is 92 used cars scraped from Charlottesville Craigslist. It sits next to this notebook
# in the repository.

# %%
import pandas as pd
import matplotlib.pyplot as plt

cars = pd.read_csv("cville_cars.csv")
print("rows, columns:", cars.shape)

cars[["title", "price", "year", "miles"]].head()

# %%
cars["price"].plot(kind="hist", bins=20, title="Charlottesville used-car prices")
plt.xlabel("price ($)")
plt.show()

# %% [markdown]
# Most of the cars are cheap, with a long tail of expensive ones. That lopsided shape is a large part of
# why this course spends September on distributions and densities rather than jumping to averages.

# %% [markdown]
# ## 3. Your setup code
#
# Everyone gets the same code, because it is computed from the data file rather than from your machine.

# %%
print(f"SETUP CODE: UU-{cars.shape[0]}-{int(cars['price'].median())}")

# %% [markdown]
# Expected, exactly: **`SETUP CODE: UU-92-5650`**
#
# Got it? Save the notebook, then commit and push it to your fork, and show the instructor or an IA both
# the code above and your commit on `github.com/YOUR-USERNAME/UU_F26`.
#
# Got something else, or an error? Flag it today. The back of the setup checklist lists the usual causes.
